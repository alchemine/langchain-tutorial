# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import DocArrayInMemorySearch

vectorstore = DocArrayInMemorySearch.from_texts(
    ["인공지능", "머신러닝", "딥러닝", "LLM", "ESG", "경영학"],
    embedding=OpenAIEmbeddings(),
)
retriever = vectorstore.as_retriever()
print(retriever.get_relevant_documents("Machine learning"))
print(retriever.get_relevant_documents("AI"))
print(retriever.get_relevant_documents("ESG 강의"))
print(
    retriever.get_relevant_documents(
        "친환경 및 사회적 책임경영과 투명경영을 통해 지속가능한 발전을 추구하는 것"
    )
)
# Out:
# /home/vscode/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/pydantic/_migration.py:283: UserWarning: `pydantic.error_wrappers:ValidationError` has been moved to `pydantic:ValidationError`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain_openai import OpenAIEmbeddings
#       2 from langchain.vectorstores import DocArrayInMemorySearch
# ----> 4 vectorstore = DocArrayInMemorySearch.from_texts(
#       5     ["인공지능", "머신러닝", "딥러닝", "LLM", "ESG", "경영학"],
#       6     embedding=OpenAIEmbeddings(),
#       7 )
#       8 retriever = vectorstore.as_retriever()
#       9 print(retriever.get_relevant_documents("Machine learning"))
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/langchain_community/vectorstores/docarray/in_memory.py:70, in DocArrayInMemorySearch.from_texts(cls, texts, embedding, metadatas, **kwargs)
#      55 """Create an DocArrayInMemorySearch store and insert data.
#      56
#      57 Args:
#    (...)
#      67     DocArrayInMemorySearch Vector Store
#      68 """
#      69 store = cls.from_params(embedding, **kwargs)
# ---> 70 store.add_texts(texts=texts, metadatas=metadatas)
#      71 return store
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/langchain_community/vectorstores/docarray/base.py:82, in DocArrayIndex.add_texts(self, texts, metadatas, **kwargs)
#      72 """Embed texts and add to the vector store.
#      73
#      74 Args:
#    (...)
#      79     List of ids from adding the texts into the vectorstore.
#      80 """
#      81 ids: List[str] = []
# ---> 82 embeddings = self.embedding.embed_documents(list(texts))
#      83 for i, (t, e) in enumerate(zip(texts, embeddings)):
#      84     m = metadatas[i] if metadatas else {}
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:526, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     523 # NOTE: to keep things simple, we assume the list may contain texts longer
#     524 #       than the maximum context and use length-safe embedding function.
#     525 engine = cast(str, self.deployment)
# --> 526 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:424, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     422 batched_embeddings: List[List[float]] = []
#     423 for i in _iter:
# --> 424     response = self.client.create(
#     425         input=tokens[i : i + _chunk_size], **self._invocation_params
#     426     )
#     427     if not isinstance(response, dict):
#     428         response = response.model_dump()
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.cache/pypoetry/virtualenvs/langchain-tutorial-9TtSrW0h-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-6hpgD***************************************a0Sa. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
